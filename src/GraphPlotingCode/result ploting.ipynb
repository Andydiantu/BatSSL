# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
list1 = [35.76, 38.37, 37.20, 37.50, 38.23]
list5 = [52.00, 52.5, 56.49, 49.52, 52.50]
list10 = [59.12,58.60, 56.19, 57.89, 59.41]
list50 = [70.1, 72.23, 72.17, 70.04, 71.44]
list100 = [76.77, 74.65, 76.48, 74.11, 77.61]

mergeList = [list1, list5, list10, list50, list100]

for i in range(len(mergeList)):
    mergeList[i] = np.array(mergeList[i])
    
supervised = mergeList

# %%
supervised = np.array(supervised)

# %%
supervised.shape
# Out:
# (5, 5)

# %%
list1 = [42.80, 41.56, 40.70, 41.37, 44.52]
list5 = [59.50, 63.01, 62.25, 59.86, 58.59]
list10 = [63.08, 64.97, 65.27, 66.21, 66.23]
list50 = [75.30, 75.38, 74.62, 74.26, 74.64]
list100 = [77.72, 76.82, 74.83,77.18, 77.85 ]

mergeList = [list1, list5, list10, list50, list100]

for i in range(len(mergeList)):
    mergeList[i] = np.array(mergeList[i])
    
autoencoder = mergeList

# %%
list1 = [45.06, 44.37, 44.93, 43.22, 41.58]
list5 = [61.28, 62.93, 61.68, 60.68, 63.16]
list10 = [65.25, 66.37, 67.20, 63.15, 66.54]
list50 = [75.02, 76.08, 74.92, 75.41, 73.92]
list100 = [77.37, 76.03, 77.03, 75.92, 76.48]
mergeList = [list1, list5, list10, list50, list100]

for i in range(len(mergeList)):
    mergeList[i] = np.array(mergeList[i])
    
simCLR = mergeList

# %%
supervised = [36,52,56,68,74]
autoEncoder = [36, 52, 59, 67, 68]
SimClR = [38, 51, 55, 65, 67]
simCLR_FineTune = [45, 63, 66, 75, 76]
data = ['1%', '5%', '10%', '50%', '100%']

# %%
plt.figure(figsize=(10, 7))
plt.plot(
    supervised, color='green', linestyle='-', marker='*',
    label='supervised'
)
# plt.plot(
#     autoEncoder, color='blue', linestyle='-', 
#     label='autoEncoder'
# )
# plt.plot(
#     SimClR, color='red', linestyle='-', 
#     label='SimClR'
# )

plt.plot(
    simCLR_FineTune, color='red', linestyle='--',  marker="X",
    label='simCLR_FineTune'
)

plt.plot(
    simCLR_FineTune, color='blue', linestyle='dashdot',  marker="o",
    label='simCLR_FineTune'
)


plt.xticks(list(range(5)), data,size = 15)
plt.yticks(size = 15)
plt.xlabel('amount of labbeled data used',size = 15)
plt.ylabel('Accuracy', size = 15)
plt.legend(fontsize = 15)
plt.savefig('list.pdf',dpi = 300)

# %%
supervised = [67.48, 72.03, 73.52, 74.52,75.05]
autoEncoder = [36.73, 52.73, 56.70, 61.85, 64.14]
SimClR = [ 41.64,52.66 ,54.87 ,59.94,62.66]
Random = [9.04, 10.71, 12.88, 13.54, 17.37]
data = ['1%', '5%', '10%', '50%', '100%']

# %%
plt.figure(figsize=(10, 7))
plt.plot(
    supervised, color='green', linestyle='-', marker='*',
    label='supervised'
)
# plt.plot(
#     autoEncoder, color='blue', linestyle='-', 
#     label='autoEncoder'
# )
# plt.plot(
#     SimClR, color='red', linestyle='-', 
#     label='SimClR'
# )

plt.plot(
    SimClR, color='red', linestyle='--',  marker="X",
    label='SimCLR'
)

plt.plot(
    autoEncoder, color='blue', linestyle='dashdot',  marker="o",
    label='Autoencoder'
)

plt.plot(
    Random, color='black', linestyle='dotted',  marker="D",
    label='Random'
)


plt.xticks(list(range(5)), data,size = 15)
plt.yticks(size = 15)
plt.xlabel('Amount of Labbeled Data Used',size = 15)
plt.ylabel('Macro Accuracy', size = 15)
plt.legend(fontsize = 15)
plt.savefig('list.pdf',dpi = 300)

# %%
list(range(5))
# Out:
# [0, 1, 2, 3, 4]

# %%
supervised_err = [...]  # Replace [...] with a list/array of error values for supervised
SimClR_err = [...]  # Replace [...] with a list/array of error values for SimClR
autoEncoder_err = [...]  # Replace [...] with a list/array of error values for autoEncoder
Random_err = [...]  # Replace [...] with a list/array of error values for Random

plt.figure(figsize=(10, 7))

x_values = list(range(5))
plt.errorbar(x_values, supervised, yerr=supervised_err, color='green', linestyle='-', marker='*', capsize=5, label='supervised')
plt.errorbar(x_values, SimClR, yerr=SimClR_err, color='red', linestyle='--', marker='X', capsize=5, label='SimCLR')
plt.errorbar(x_values, autoEncoder, yerr=autoEncoder_err, color='blue', linestyle='dashdot', marker='o', capsize=5, label='Autoencoder')
plt.errorbar(x_values, Random, yerr=Random_err, color='black', linestyle='dotted', marker='D', capsize=5, label='Random')

plt.xticks(x_values, data, size=15)
plt.yticks(size=15)
plt.xlabel('Amount of Labbeled Data Used', size=15)
plt.ylabel('Macro Accuracy', size=15)
plt.legend(fontsize=15)
plt.savefig('list_with_errorbars.pdf', dpi=300)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 9>()
#       6 plt.figure(figsize=(10, 7))
#       8 x_values = list(range(5))
# ----> 9 plt.errorbar(x_values, supervised, yerr=supervised_err, color='green', linestyle='-', marker='*', capsize=5, label='supervised')
#      10 plt.errorbar(x_values, SimClR, yerr=SimClR_err, color='red', linestyle='--', marker='X', capsize=5, label='SimCLR')
#      11 plt.errorbar(x_values, autoEncoder, yerr=autoEncoder_err, color='blue', linestyle='dashdot', marker='o', capsize=5, label='Autoencoder')
#
# NameError: name 'supervised' is not defined

# %%
import numpy as np

supervised_data = supervised  # Replace [...] with a list of lists or 2D array of data for supervised
SimClR_data = simCLR  # Replace [...] with a list of lists or 2D array of data for SimClR
autoEncoder_data = autoencoder  # Replace [...] with a list of lists or 2D array of data for autoEncoder
Random_data = autoencoder  # Replace [...] with a list of lists or 2D array of data for Random

supervised_data = np.array(supervised_data)
SimClR_data = np.array(SimClR_data)
autoEncoder_data = np.array(autoEncoder_data)
Random_data = np.array(Random_data)

print(supervised_data.shape)

supervised_mean = np.mean(supervised_data, axis=1)
SimClR_mean = np.mean(SimClR_data, axis=1)
autoEncoder_mean = np.mean(autoEncoder_data, axis=1)
Random_mean = np.mean(Random_data, axis=1)

supervised_std = np.std(supervised_data, axis=1)
SimClR_std = np.std(SimClR_data, axis=1)
autoEncoder_std = np.std(autoEncoder_data, axis=1)
Random_std = np.std(Random_data, axis=1)

# If you want to calculate the standard error of the mean (SEM), use:
supervised_sem = supervised_std / np.sqrt(supervised_data.shape[0])
SimClR_sem = SimClR_std / np.sqrt(SimClR_data.shape[0])
autoEncoder_sem = autoEncoder_std / np.sqrt(autoEncoder_data.shape[0])
Random_sem = Random_std / np.sqrt(Random_data.shape[0])
# Out:
# (5, 5)

# %%
plt.figure(figsize=(10, 7))

x_values = list(range(5))
plt.errorbar(x_values, supervised_mean, yerr=supervised_std, color='green', linestyle='-', marker='*', capsize=5, label='supervised')
plt.errorbar(x_values, SimClR_mean, yerr=SimClR_std, color='red', linestyle='--', marker='X', capsize=5, label='SimCLR')
plt.errorbar(x_values, autoEncoder_mean, yerr=autoEncoder_std, color='blue', linestyle='dashdot', marker='o', capsize=5, label='Autoencoder')
# plt.errorbar(x_values, Random_mean, yerr=Random_std, color='black', linestyle='dotted', marker='D', capsize=5, label='Random')

plt.xticks(x_values, data, size=15)
plt.yticks(size=15)
plt.xlabel('Amount of Labbeled Data Used', size=15)
plt.ylabel('Macro Accuracy', size=15)
plt.legend(fontsize=15)
plt.savefig('list_with_errorbars.pdf', dpi=300)
